# %%
import pandas as pd

df = pd.read_csv("./pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
legendary_pokemons = True
df.loc[df['Legendary'] == legendary_pokemons]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("./pokemon_data.csv")
print(df["Defense"].skew())
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sb.distplot(df["Defense"])
plt.subplot(1,2,2)
sb.boxplot(y="Defense", data=df)
# Out:
# 1.1559123029560856
# C:\Users\oclou\AppData\Local\Temp\ipykernel_5604\710547867.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df["Defense"])
# <Axes: ylabel='Defense'>

# %%
# we need 25% percentile and 75% 
# df["Defense"].describe()

percentile25 = df["Defense"].quantile(0.25)
percentile75 = df["Defense"].quantile(0.75)
print(percentile25, percentile75)

iqr = percentile75 - percentile25
print(iqr)

h_bound = percentile75 + 1.5 * iqr
l_bound = percentile25 - 1.5 * iqr

print(h_bound, l_bound)

# %%
# Trimining Outliars

# df.loc[(df["Defense"] > h_bound) | (df["Defense"] < l_bound)]
# new_df = df[(df["Defense"] < h_bound) & (df["Defense"] > l_bound)]
# new_df

# %%
# Capping outliars

# df["Defense"] = np.where(df["Defense"]>h_bound, 
#          h_bound,
#          np.where(df["Defense"]<l_bound, 
#          l_bound,
#          df["Defense"]))
# df["Defense"]
